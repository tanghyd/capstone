# %%
import re
import os
import glob
from pathlib import Path
import json
from shutil import copyfile
import itertools
from collections import Counter

# analytics
import pandas as pd
import numpy as np

# Spacy Imports
import spacy

from spacy import displacy
from spacy.pipeline import EntityRuler
from spacy.matcher import PhraseMatcher
from spacy.tokens import Doc, Span, Token
from spacy.attrs import intify_attrs

def display_ent(doc):
    displacy.render(doc, style="ent", jupyter=True)

# %%
# Project Base
base_path = Path('..')

# Event Path
events_path = base_path / 'events'

# dictionary path
dictionary_path = base_path / 'dictionary'
triggers_path = dictionary_path / 'triggers'
patterns_path = dictionary_path / 'patterns'

# %%
# load patterns for simple geological NER during labelling process
patterns = []
for filename in patterns_path.iterdir():
    with open(filename, encoding="utf8") as f:
        patterns += json.load(f)
        
print(f'loaded {len(patterns)} patterns')

spacy_model = "en_core_web_lg"
nlp = spacy.load(spacy_model)
print(f'loaded {spacy_model} as nlp')

# add loaded patterns to spacy model pipeline
ruler = EntityRuler(nlp, overwrite_ents=True)
ruler.add_patterns(patterns)

nlp.add_pipe(ruler)
# Out:
# loaded 31120 patterns
# loaded en_core_web_lg as nlp

# %%
# specify your group number here
event_group = 6

# if in process of labelling data, load previously reviewed event datta
with events_path.joinpath(f'group_{event_group}_labelled.csv').resolve() as file_path:
    if os.path.isfile(file_path):  # check if file exists
        df = pd.read_csv(file_path)
        print(f'Loaded pre-labelled data from {file_path}')
    else:  # else if labelling-in-progress csv does not exist try loading the unlabelled version
        try:
            print(f'Previously labelled data does not exist - loading group_{event_group}_events.csv')
            df = pd.read_csv(events_path.joinpath(f'group_{event_group}_events.csv').resolve())
            df['reviewed'] = False
        except Exception as e:  # error handling
            print(f'File probably does not exist. Please extract events and save to {events_path.resolve()}')
            print(e)
# Out:
# Previously labelled data does not exist - loading group_6_events.csv

# %%
df.iloc[0].T
# Out:
# event_id                        a072171_2005 everlasting annual rpt_12941703_1
# filename                     a072171_2005 everlasting annual rpt_12941703.json
# sentence_idx                                                                 1
# sentence_text                a detailed report titled potential of the nors...
# n_trigger_words                                                              1
# trigger_words_in_sentence                                        ['potential']
# trigger_words_in_event                         ['potential', 'mineralisation']
# event_text                   the norseman project has significant explorati...
# ORE_DEPOSIT                                                                 []
# ROCK                                                                        []
# MINERAL                                                                     []
# STRAT                                                                       []
# LOCATION                                  ['norseman', 'norseman', 'norseman']
# TIMESCALE                                                                   []
# event_label                                                                  0
# reviewed                                                                 False
# Name: 0, dtype: object

# %%
# clear cell display if desired
from IPython.display import clear_output
clear_cell_display = True

for idx, row in df.loc[~df.reviewed].iterrows():
    # print event information
    print(f'File Index {idx} - File Name : {row.filename}\n')
    print(row.event_text)
    print('')
    print("The trigger word(s) detected in this text chunck were: {}".format(row.trigger_words_in_sentence))
    print('')
    print("The sentence that the trigger word occured in was: {}.".format(row.sentence_text))
    print(display_ent(nlp(row.event_text)))
    
    
    # take user input
    label = input("\nIs this a near miss event?(True/False)\n")
    reviewed = True
    
    # if user response is true, then mark as near miss and query for reasoning
    if label.lower() in ["yes", "y","ye", "yeah", "true", "t"]:
        label = True
        trigger_phrase = input("""
        \n Was there a phrase/word that indicated that this was a near miss event? Please type phrase that can be added to trigger phrases, leave blank if none\n""")
    
    # if user response is false, then mark accordingly witth no trigger phrase
    elif label.lower() in ["n",  "no", "nope", "nah", "false", "f"]:
        label = False
        trigger_phrase = ''
    
    # if near miss label is uncertain, leave as unreviewed so as to come back later.
    elif label.lower() in ['u','unknown','none']:
        print('Not specifying a label for this sentence.')
        reviewed = False
        
    # allow text input for quit
    elif label.lower() in ["q","quit","stop",'exit']:
        break
        
    # invalid input
    else:
        print('Input did not match list of valid commands.')
        print(f'Input received was {label}')
        print('Try: "true" (or "T"), "false" (or "F"), "unknown" (or "U"), or "quit" (or "Q").')
        break
        
    print(f'label = {label}')
    df.loc[idx,'Near Miss Event'] = label
    df.loc[idx, 'reviewed'] = reviewed
    df.loc[idx, 'Key trigger phrase'] = trigger_phrase
    print('')
    
    # clear cell output if true
    if clear_cell_display:
        clear_output()
# Out:
# File Index 0 - File Name : a072171_2005 everlasting annual rpt_12941703.json
#
# the norseman project has significant exploration upside. a detailed report titled potential of the norseman project 2002 identifies most significant targets. the powerpoint, norseman exploration eoy 2004 also provides an illustrative overview. better definition of soil anomalies is required and an mmi survey has been recommended in order to address all the various styles of mineralisation and various previously unrecognised structural trends.
#
# The trigger word(s) detected in this text chunck were: ['potential']
#
# The sentence that the trigger word occured in was: a detailed report titled potential of the norseman project 2002 identifies most significant targets..
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     norseman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOCATION</span>
# </mark>
#  project has significant exploration upside. a detailed report titled potential of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     norseman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOCATION</span>
# </mark>
#  project
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2002
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  identifies most significant targets. the powerpoint,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     norseman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOCATION</span>
# </mark>
#  exploration eoy 2004 also provides an illustrative overview. better definition of soil anomalies is required and an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mmi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  survey has been recommended in order to address all the various styles of mineralisation and various previously unrecognised structural trends.</div></span>
# None

# %%
# view reviewed events
df.loc[df.reviewed]
# Out:
#      Unnamed: 0                                           event_id  \
# 0             0          a081752_anrep2008eraheedy2103_15107355_16
# 1             1           a075210_buck_a_ el12_1_2007_11292066_235
# 2             2           a075210_buck_a_ el12_1_2007_11292066_246
# 3             3                  a080379_e80_2574_08atr_12876104_4
# 4             4                  a080379_e80_2574_08atr_12876104_5
# ..          ...                                                ...
# 96           96  a072786_carlow castle 2005a c453-1996_14242581...
# 97           97  a072786_carlow castle 2005a c453-1996_14242581...
# 98           98  a072786_carlow castle 2005a c453-1996_14242581...
# 99           99  a072786_carlow castle 2005a c453-1996_14242581...
# 100         100  a072786_carlow castle 2005a c453-1996_14242581...
#
#                                               filename  sentence_idx  \
# 0          a081752_anrep2008eraheedy2103_15107355.json            16
# 1            a075210_buck_a_ el12_1_2007_11292066.json           235
# 2            a075210_buck_a_ el12_1_2007_11292066.json           246
# 3                 a080379_e80_2574_08atr_12876104.json             4
# 4                 a080379_e80_2574_08atr_12876104.json             5
# ..                                                 ...           ...
# 96   a072786_carlow castle 2005a c453-1996_14242581...           223
# 97   a072786_carlow castle 2005a c453-1996_14242581...           227
# 98   a072786_carlow castle 2005a c453-1996_14242581...           228
# 99   a072786_carlow castle 2005a c453-1996_14242581...           233
# 100  a072786_carlow castle 2005a c453-1996_14242581...           234
#
#                                          sentence_text  n_trigger_words  \
# 0    mineral occurrences and exploration potential ...                1
# 1    further drilling in coming years will further ...                1
# 2    the tenement was applied for on the 12 1 2005 ...                1
# 3    the east kimberley halls creek orogen is widel...                2
# 4    hoatson also recognized broad similarities bet...                1
# ..                                                 ...              ...
# 96   the discovery of a blind high grade copper gol...                3
# 97   such a mineral resource could be the basis for...                1
# 98   the work by legend has outlined several other ...                1
# 99   in particular, the prospects se of carlow cast...                1
# 100  this spatial distribution of the shears, toget...                1
#
#                                       trigger_words  \
# 0                                     ['potential']
# 1                              ['further drilling']
# 2                                      ['possible']
# 3                   ['potential', 'mineralisation']
# 4                                         ['broad']
# ..                                              ...
# 96   ['low grade', 'mineralisation', 'encouraging']
# 97                                        ['broad']
# 98                               ['mineralisation']
# 99                                     ['possible']
# 100                                    ['possible']
#
#                                             event_text  \
# 0    resource search pty ltd. september 2008 2 the ...
# 1    of days worked at $ $ construction materials: ...
# 2    60 appendix 3: coal resources within el12 1 66...
# 3    the planned ground magnetics survey should be ...
# 4    the planned ground magnetics survey should be ...
# ..                                                 ...
# 96   based on the results of this program, openpit ...
# 97   near sing well a few small open pits were sunk...
# 98   exploration in the carlow castle area has conf...
# 99   such a mineral resource could be the basis for...
# 100  the work by legend has outlined several other ...
#
#                                    ORE_DEPOSIT  \
# 0                                  ['uranium']
# 1                                           []
# 2                                           []
# 3                                      ['pge']
# 4                               ['pge', 'pge']
# ..                                         ...
# 96   ['lodes', 'lode', 'lode', 'lode', 'lode']
# 97            ['lode', 'lode', 'lode', 'lode']
# 98            ['lode', 'lode', 'lode', 'lode']
# 99                            ['lode', 'lode']
# 100                                   ['lode']
#
#                                                   ROCK  \
# 0    ['calcrete', 'granite', 'sediments', 'silts', ...
# 1                                     ['coal', 'coal']
# 2      ['coal', 'coal', 'ash', 'coal', 'coal', 'coal']
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 96                                   ['serpentinites']
# 97                          ['serpentinites', 'chert']
# 98                                 ['chert', 'gabbro']
# 99                                 ['chert', 'gabbro']
# 100                                ['chert', 'gabbro']
#
#                                                MINERAL                STRAT  \
# 0                                                   []                   []
# 1                                                   []                   []
# 2                               ['diamond', 'sulphur']                   []
# 3                     ['gold', 'sulphide', 'sulphide']                   []
# 4                     ['gold', 'sulphide', 'sulphide']                   []
# ..                                                 ...                  ...
# 96   ['gold', 'copper', 'gold', 'gold', 'copper', '...                   []
# 97   ['gold', 'copper', 'copper', 'gold', 'copper',...                   []
# 98   ['gold', 'copper', 'copper', 'gold', 'copper',...  ['andover complex']
# 99   ['copper', 'gold', 'copper', 'gold', 'copper',...  ['andover complex']
# 100  ['copper', 'gold', 'copper', 'gold', 'copper',...  ['andover complex']
#
#                                               LOCATION  \
# 0    ['nabberu basin', 'western australia', 'wester...
# 1                  ['ewington', 'premier', 'ewington']
# 2             ['muja', 'collie', 'ewington', 'collie']
# 3     ['kimberley', 'halls creek orogen', 'australia']
# 4     ['kimberley', 'halls creek orogen', 'australia']
# ..                                                 ...
# 96                                                  []
# 97                                                  []
# 98                                                  []
# 99                            ['south west', 'whundo']
# 100  ['south west', 'whundo', 'perth', 'pilbara reg...
#
#                              TIMESCALE  event_label  reviewed Near Miss Event  \
# 0    ['paleoproterozoic', 'cainozoic']            0      True            True
# 1                                   []            0      True            True
# 2                                   []            0      True            adfg
# 3                                   []            0      True            True
# 4                                   []            0      True            True
# ..                                 ...          ...       ...             ...
# 96                                  []            0      True            True
# 97                                  []            0      True           False
# 98                                  []            0      True            True
# 99                                  []            0      True            True
# 100                                 []            0      True            True
#
#                                     Key trigger phrase
# 0    weakly anomalous, studies to confirm the valid...
# 1                                    prospective areas
# 2                                    prospective areas
# 3
# 4    economic interest, extensively mineralized, ex...
# ..                                                 ...
# 96
# 97
# 98                     extension to the mineralisation
# 99
# 100           possible presence of a large mineralised
#
# [101 rows x 18 columns]

# %%
# # fix indices by "un-reviewing them"
# for i in (4,5):
#     df.loc[i,'reviewed'] = False
    
# df.loc[df.reviewed]

# %%
# export csv when done
save_path = events_path.joinpath(f'group_{event_group}_labelled.csv').resolve()
df.to_csv(save_path)
print(f'Saved group {event_group} labelled data to {save_path}')
# Out:
# Saved group 2 labelled data to /home/daniel/capstone/events/group_2_labelled.csv
