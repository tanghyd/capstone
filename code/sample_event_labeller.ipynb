# %%
import re
import os
import glob
from pathlib import Path
import json
from shutil import copyfile
import itertools
from collections import Counter

# analytics
import pandas as pd
import numpy as np

# Spacy Imports
import spacy

from spacy import displacy
from spacy.pipeline import EntityRuler
from spacy.matcher import PhraseMatcher
from spacy.tokens import Doc, Span, Token
from spacy.attrs import intify_attrs

def display_ent(doc):
    displacy.render(doc, style="ent", jupyter=True)

spacy_model = "en_core_web_sm"
#spacy_model = "en_core_web_lg"

nlp = spacy.load(spacy_model)

# %%
# Project Base
base_path = Path('..')

# Event Path
events_path = base_path / 'events'

# %%
# specify your group number here
event_group = 2

# if in process of labelling data, load previously reviewed event datta
with events_path.joinpath(f'group_{event_group}_labelled.csv').resolve() as file_path:
    if os.path.isfile(file_path):  # check if file exists
        df = pd.read_csv(file_path)
    else:  # else if labelling-in-progress csv does not exist try loading the unlabelled version
        try:
            print(f'Previously labelled data does not exist - loading group_{event_group}_events.csv')
            df = pd.read_csv(events_path.joinpath(f'group_{event_group}_events.csv').resolve())
            df['reviewed'] = False
        except Exception as e:  # error handling
            print(f'File probably does not exist. Please extract events and save to {events_path.resolve()}')
            print(e)
# Out:
# Previously labelled data does not exist - loading group_2_events.csv

# %%
# clear cell display if desired
from IPython.display import clear_output
clear_cell_display = True

for idx, row in df.loc[~df.reviewed].iterrows():
    # print event information
    print(f'File Index {idx} - File Name : {row.filename}\n')
    print(row.sentence_text)
    print('')
    print(display_ent(nlp(row.sentence_text)))
    
    # take user input
    label = input("\nIs this a near miss event? ")
    
    # exit
    if label == 'stop':
        break
    
    
    print(f'label = {label}')
    df.loc[idx,'event_label'] = label
    df.loc[idx, 'reviewed'] = True
    print('')
    
    # clear cell output if true
    if clear_cell_display:
        clear_output()
# Out:
# File Index 0 - File Name : a081752_anrep2008eraheedy2103_15107355.json
#
# project name: granite peak tenement numbers: e69 2103 tenement operator: atomic resources limited tenement holder: resource search pty ltd report type: annual report period: 1st september 2007 30th august 2008 author: atomic resources date of report: 30 october 2008 1:250 000 map sheet: nabberu ( sg51 5) 1:100,000 map sheet : nabberu ( 3046) target commodity: gold, copper, uranium prospects drilled: nil.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">project name: granite peak tenement numbers: e69
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2103
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  tenement operator: atomic resources limited tenement holder: resource search pty ltd report type:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     annual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  report period:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1st
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     september 2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30th august 2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  author: atomic resources date of report:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30 october 2008 1:250
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  000 map sheet: nabberu ( sg51
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# )
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1:100,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  map sheet : nabberu (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3046
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ) target commodity: gold, copper, uranium prospects drilled:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</div></span>
# None
#
# Is this a near miss event? stop

# %%
df
# Out:
#                                                event_id  \
# 0              a081752_anrep2008eraheedy2103_15107355_1
# 1              a081752_anrep2008eraheedy2103_15107355_2
# 2             a081752_anrep2008eraheedy2103_15107355_16
# 3             a081752_anrep2008eraheedy2103_15107355_20
# 4               a075210_buck_a_ el12_1_2007_11292066_45
# ...                                                 ...
# 2273  a080097_microsoft word - 081110_e52_1711_parti...
# 2274  a080097_microsoft word - 081110_e52_1711_parti...
# 2275  a080097_microsoft word - 081110_e52_1711_parti...
# 2276  a080097_microsoft word - 081110_e52_1711_parti...
# 2277  a080097_microsoft word - 081110_e52_1711_parti...
#
#                                                filename  sentence_idx  \
# 0           a081752_anrep2008eraheedy2103_15107355.json             1
# 1           a081752_anrep2008eraheedy2103_15107355.json             2
# 2           a081752_anrep2008eraheedy2103_15107355.json            16
# 3           a081752_anrep2008eraheedy2103_15107355.json            20
# 4             a075210_buck_a_ el12_1_2007_11292066.json            45
# ...                                                 ...           ...
# 2273  a080097_microsoft word - 081110_e52_1711_parti...            38
# 2274  a080097_microsoft word - 081110_e52_1711_parti...            39
# 2275  a080097_microsoft word - 081110_e52_1711_parti...            43
# 2276  a080097_microsoft word - 081110_e52_1711_parti...            46
# 2277  a080097_microsoft word - 081110_e52_1711_parti...            47
#
#                                           sentence_text  n_trigger_words  \
# 0     project name: granite peak tenement numbers: e...                1
# 1     the project comprises one exploration licence ...                1
# 2     mineral occurrences and exploration potential ...                1
# 3     results: follow up targets identified fro fiel...                2
# 4     92.670 0.200 139441 sandstone (75%): light, bu...                1
# ...                                                 ...              ...
# 2273  anaconda nickel ltd conducted a shallow rc and...                1
# 2274  drilling and metallurgical test results indica...                1
# 2275  the focus of the work was to identify areas of...                2
# 2276  neither sampling media identified any anomalie...                1
# 2277  references cooper, r.w, langford, r.l., pirajn...                1
#
#                         trigger_words  \
# 0                           ['drill']
# 1             ['exploration licence']
# 2                       ['potential']
# 3              ['drill', 'follow up']
# 4                           ['minor']
# ...                               ...
# 2273                    ['potential']
# 2274                      ['contain']
# 2275  ['potential', 'mineralisation']
# 2276                    ['follow up']
# 2277                    ['potential']
#
#                                              event_text  ORE_DEPOSIT  \
# 0     annual report for the year ending 1st septembe...  ['uranium']
# 1     annual report for the year ending 1st septembe...  ['uranium']
# 2     bibliography bunting ja 1986, geology of the e...           []
# 3     geology: located within the paleoproterozoic e...           []
# 4     top of e25 seam 75.480 0.960 139439 coal undif...           []
# ...                                                 ...          ...
# 2273  this prospect is currently inactive due to nat...           []
# 2274  the mineralisation may be co genetic with that...           []
# 2275  exploration exploration work completed over th...           []
# 2276  the geochemical response within the surrendere...           []
# 2277  the co incident elevated gold responses in bot...           []
#
#                                                    ROCK  \
# 0                                           ['granite']
# 1                                           ['granite']
# 2                                           ['granite']
# 3           ['sediments', 'silts', 'sands', 'calcrete']
# 4     ['coal', 'sandstone', 'sandstone', 'coal', 'sa...
# ...                                                 ...
# 2273                          ['laterite', 'laterites']
# 2274                          ['laterite', 'laterites']
# 2275                                            ['lag']
# 2276                                                 []
# 2277                                                 []
#
#                                         MINERAL STRAT  \
# 0                            ['gold', 'copper']    []
# 1                            ['gold', 'copper']    []
# 2                                            []    []
# 3                                            []    []
# 4                          ['pyrite', 'pyrite']    []
# ...                                         ...   ...
# 2273                                 ['nickel']    []
# 2274  ['nickel', 'nickel', 'sulphides', 'gold']    []
# 2275                           ['gold', 'gold']    []
# 2276                           ['gold', 'gold']    []
# 2277                                   ['gold']    []
#
#                                                LOCATION  \
# 0                                                    []
# 1                                            ['wiluna']
# 2     ['nabberu basin', 'western australia', 'wester...
# 3                                                    []
# 4                              ['grey', 'grey', 'grey']
# ...                                                 ...
# 2273                                                 []
# 2274                                                 []
# 2275                                                 []
# 2276                                ['bangemall basin']
# 2277           ['bangemall basin', 'western australia']
#
#                               TIMESCALE  event_label  reviewed
# 0                                    []            0     False
# 1                  ['paleoproterozoic']            0     False
# 2                                    []            0     False
# 3     ['paleoproterozoic', 'cainozoic']            0     False
# 4                                    []            0     False
# ...                                 ...          ...       ...
# 2273                                 []            0     False
# 2274                                 []            0     False
# 2275                                 []            0     False
# 2276                                 []            0     False
# 2277                                 []            0     False
#
# [2278 rows x 15 columns]

# %%
# export csv when done
df.to_csv(f'group_{event_group}_labelled.csv')
print(f'Saved group_{event_group}_labelled.csv')
