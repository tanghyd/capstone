# %%
import re
import os
import glob
from pathlib import Path
import json
from shutil import copyfile
import itertools
from collections import Counter

# analytics
import pandas as pd
import numpy as np

# Spacy Imports
import spacy

from spacy import displacy
from spacy.pipeline import EntityRuler
from spacy.matcher import PhraseMatcher
from spacy.tokens import Doc, Span, Token
from spacy.attrs import intify_attrs

def display_ent(doc):
    displacy.render(doc, style="ent", jupyter=True)

spacy_model = "en_core_web_sm"
#spacy_model = "en_core_web_lg"

nlp = spacy.load(spacy_model)

# %%
# Project Base
base_path = Path('..')

# Event Path
events_path = base_path / 'events'

# %%
# specify your group number here
event_group = 6

# if in process of labelling data, load previously reviewed event datta
with events_path.joinpath(f'group_{event_group}_labelled.csv').resolve() as file_path:
    if os.path.isfile(file_path):  # check if file exists
        df = pd.read_csv(file_path)
    else:  # else if labelling-in-progress csv does not exist try loading the unlabelled version
        try:
            print(f'Previously labelled data does not exist - loading group_{event_group}_events.csv')
            df = pd.read_csv(events_path.joinpath(f'group_{event_group}_events.csv').resolve())
            df['reviewed'] = False
        except Exception as e:  # error handling
            print(f'File probably does not exist. Please extract events and save to {events_path.resolve()}')
            print(e)

df
# Out:
# Previously labelled data does not exist - loading group_6_events.csv
#                                               event_id  \
# 0       a072171_2005 everlasting annual rpt_12941703_1
# 1       a072171_2005 everlasting annual rpt_12941703_3
# 2       a072171_2005 everlasting annual rpt_12941703_6
# 3      a072171_2005 everlasting annual rpt_12941703_11
# 4      a072171_2005 everlasting annual rpt_12941703_59
# ..                                                 ...
# 696  a086030_20-100-go-ann-0008_ks_annual_report_20...
# 697  a086030_20-100-go-ann-0008_ks_annual_report_20...
# 698  a086030_20-100-go-ann-0008_ks_annual_report_20...
# 699  a086030_20-100-go-ann-0008_ks_annual_report_20...
# 700  a086030_20-100-go-ann-0008_ks_annual_report_20...
#
#                                               filename  sentence_idx  \
# 0    a072171_2005 everlasting annual rpt_12941703.json             1
# 1    a072171_2005 everlasting annual rpt_12941703.json             3
# 2    a072171_2005 everlasting annual rpt_12941703.json             6
# 3    a072171_2005 everlasting annual rpt_12941703.json            11
# 4    a072171_2005 everlasting annual rpt_12941703.json            59
# ..                                                 ...           ...
# 696  a086030_20-100-go-ann-0008_ks_annual_report_20...            24
# 697  a086030_20-100-go-ann-0008_ks_annual_report_20...            30
# 698  a086030_20-100-go-ann-0008_ks_annual_report_20...            44
# 699  a086030_20-100-go-ann-0008_ks_annual_report_20...            91
# 700  a086030_20-100-go-ann-0008_ks_annual_report_20...            95
#
#                                          sentence_text  n_trigger_words  \
# 0    a detailed report titled potential of the nors...                1
# 1    better definition of soil anomalies is require...                1
# 2           exploration potential and recommendations.                1
# 3    croesus have recently developed and mined by o...                1
# 4    the area around the gladstone and daisy teneme...                1
# ..                                                 ...              ...
# 696  westralian iron pty ltd 20 100 go ann 0008 com...                1
# 697  the synform broadly consists of a middle sedim...                1
# 698  very extensive magnetite rich, steeply dipping...                1
# 699  broad acre farming including wheat cropping an...                1
# 700  individual hills denoting structurally discret...                2
#
#                        trigger_words  \
# 0                      ['potential']
# 1                 ['mineralisation']
# 2                      ['potential']
# 3                 ['mineralisation']
# 4                 ['mineralisation']
# ..                               ...
# 696                    ['extensive']
# 697                    ['extensive']
# 698                    ['extensive']
# 699                        ['broad']
# 700  ['potential', 'mineralisation']
#
#                                             event_text   ORE_DEPOSIT  \
# 0    the norseman project has significant explorati...            []
# 1    a detailed report titled potential of the nors...            []
# 2    regional geological setting . exploration comp...            []
# 3    the everlasting project covers an area of 436 ...            []
# 4    archaean lithology the dominant archaean litho...            []
# ..                                                 ...           ...
# 696  archaean granitoid rocks: ago, ags in the nort...            []
# 697  weathering has transformed the near surface bi...  ['limonite']
# 698  the koolanooka hills comprises of a nnw trendi...            []
# 699  the closest population centres are morawa, loc...  ['iron ore']
# 700  the mining leases are elongate north south and...  ['iron ore']
#
#                                                   ROCK  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                     ['banded iron formation', 'bif']
# 4    ['basalt', 'dolerite', 'gabbro', 'metasediment...
# ..                                                 ...
# 696  ['granitoid', 'granitoid', 'gneiss', 'granite'...
# 697  ['bif', 'laterite', 'granitoid', 'granitoid', ...
# 698    ['banded iron formation', 'bif', 'bif', 'bifs']
# 699                                                 []
# 700                                            ['bif']
#
#                                        MINERAL  \
# 0                                           []
# 1                                           []
# 2                                           []
# 3                                           []
# 4                           ['gold', 'zircon']
# ..                                         ...
# 696  ['quartz', 'feldspar', 'biotite', 'iron']
# 697                   ['hematite', 'goethite']
# 698                  ['magnetite', 'hematite']
# 699                                         []
# 700                      ['iron', 'magnetite']
#
#                                               STRAT  \
# 0                                                []
# 1                                                []
# 2                                                []
# 3     ['penneshaw formation', 'noganyer formation']
# 4    ['penneshaw formation', 'penneshaw formation']
# ..                                              ...
# 696                                              []
# 697                                              []
# 698                                              []
# 699                                              []
# 700                                              []
#
#                                               LOCATION  \
# 0                 ['norseman', 'norseman', 'norseman']
# 1                             ['norseman', 'norseman']
# 2                                                   []
# 3    ['norseman', 'gladstone', 'gladstone', 'gladst...
# 4                   ['gladstone', 'gladstone', 'long']
# ..                                                 ...
# 696                       ['south west', 'koolanooka']
# 697                                     ['koolanooka']
# 698  ['koolanooka', 'mid west', 'western australia'...
# 699              ['morawa', 'perenjori', 'koolanooka']
# 700  ['koolanooka', 'koolanooka', 'southwest', 'koo...
#
#                                             TIMESCALE  event_label  reviewed
# 0                                                  []            0     False
# 1                                                  []            0     False
# 2                                                  []            0     False
# 3                                                  []            0     False
# 4                ['archaean', 'archaean', 'archaean']            0     False
# ..                                                ...          ...       ...
# 696  ['archaean', 'tertiary', 'tertiary', 'archaean']            0     False
# 697                                      ['archaean']            0     False
# 698                                                []            0     False
# 699                                                []            0     False
# 700                                                []            0     False
#
# [701 rows x 15 columns]

# %%
# clear cell display if desired
from IPython.display import clear_output
clear_cell_display = True

for idx, row in df.loc[~df.reviewed].iterrows():
    # print event information
    print(f'File Index {idx} - File Name : {row.filename}\n')
    print(row.event_text)
    print('')
    print("The trigger word(s) detected in this text chunck were: {}".format(row.trigger_words))
    print(display_ent(nlp(row.event_text)))
    
    # take user input
    label = input("\nIs this a near miss event?(True/False) ")
    
    if label in ["Yes", "y","Y","ye", "yeah", "True", "true"]:
        label = True
        trigger_phrase = input("""\n Was there a phrase/word that indicated that this was a near miss event?
                              please type phrase that can be added to trigger phrases, leave blank if none""")
    elif label == "stop":
        break
    else:
        label = False
    # exit
    
    print(f'label = {label}')
    df.loc[idx,'Near Miss Event'] = label
    df.loc[idx, 'reviewed'] = True
    df.loc[idx, 'Key trigger phrase'] = trigger_phrase
    print('')
    
    # clear cell output if true
    if clear_cell_display:
        clear_output()
# Out:
# File Index 0 - File Name : a072171_2005 everlasting annual rpt_12941703.json
#
# the norseman project has significant exploration upside. a detailed report titled potential of the norseman project 2002 identifies most significant targets. the powerpoint, norseman exploration eoy 2004 also provides an illustrative overview.
#
# The trigger word(s) detected in this text chunck were: ['potential']
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     norseman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  project has significant exploration upside. a detailed report titled potential of the
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     norseman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  project
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2002
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  identifies most significant targets. the powerpoint, norseman exploration eoy
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2004
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  also provides an illustrative overview.</div></span>
# None
#
# Is this a near miss event?(True/False) stop

# %%
df
# Out:
#                                               event_id  \
# 0       a072171_2005 everlasting annual rpt_12941703_1
# 1       a072171_2005 everlasting annual rpt_12941703_3
# 2       a072171_2005 everlasting annual rpt_12941703_6
# 3      a072171_2005 everlasting annual rpt_12941703_11
# 4      a072171_2005 everlasting annual rpt_12941703_59
# ..                                                 ...
# 696  a086030_20-100-go-ann-0008_ks_annual_report_20...
# 697  a086030_20-100-go-ann-0008_ks_annual_report_20...
# 698  a086030_20-100-go-ann-0008_ks_annual_report_20...
# 699  a086030_20-100-go-ann-0008_ks_annual_report_20...
# 700  a086030_20-100-go-ann-0008_ks_annual_report_20...
#
#                                               filename  sentence_idx  \
# 0    a072171_2005 everlasting annual rpt_12941703.json             1
# 1    a072171_2005 everlasting annual rpt_12941703.json             3
# 2    a072171_2005 everlasting annual rpt_12941703.json             6
# 3    a072171_2005 everlasting annual rpt_12941703.json            11
# 4    a072171_2005 everlasting annual rpt_12941703.json            59
# ..                                                 ...           ...
# 696  a086030_20-100-go-ann-0008_ks_annual_report_20...            24
# 697  a086030_20-100-go-ann-0008_ks_annual_report_20...            30
# 698  a086030_20-100-go-ann-0008_ks_annual_report_20...            44
# 699  a086030_20-100-go-ann-0008_ks_annual_report_20...            91
# 700  a086030_20-100-go-ann-0008_ks_annual_report_20...            95
#
#                                          sentence_text  n_trigger_words  \
# 0    a detailed report titled potential of the nors...                1
# 1    better definition of soil anomalies is require...                1
# 2           exploration potential and recommendations.                1
# 3    croesus have recently developed and mined by o...                1
# 4    the area around the gladstone and daisy teneme...                1
# ..                                                 ...              ...
# 696  westralian iron pty ltd 20 100 go ann 0008 com...                1
# 697  the synform broadly consists of a middle sedim...                1
# 698  very extensive magnetite rich, steeply dipping...                1
# 699  broad acre farming including wheat cropping an...                1
# 700  individual hills denoting structurally discret...                2
#
#                        trigger_words  \
# 0                      ['potential']
# 1                 ['mineralisation']
# 2                      ['potential']
# 3                 ['mineralisation']
# 4                 ['mineralisation']
# ..                               ...
# 696                    ['extensive']
# 697                    ['extensive']
# 698                    ['extensive']
# 699                        ['broad']
# 700  ['potential', 'mineralisation']
#
#                                             event_text   ORE_DEPOSIT  \
# 0    the norseman project has significant explorati...            []
# 1    a detailed report titled potential of the nors...            []
# 2    regional geological setting . exploration comp...            []
# 3    the everlasting project covers an area of 436 ...            []
# 4    archaean lithology the dominant archaean litho...            []
# ..                                                 ...           ...
# 696  archaean granitoid rocks: ago, ags in the nort...            []
# 697  weathering has transformed the near surface bi...  ['limonite']
# 698  the koolanooka hills comprises of a nnw trendi...            []
# 699  the closest population centres are morawa, loc...  ['iron ore']
# 700  the mining leases are elongate north south and...  ['iron ore']
#
#                                                   ROCK  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                     ['banded iron formation', 'bif']
# 4    ['basalt', 'dolerite', 'gabbro', 'metasediment...
# ..                                                 ...
# 696  ['granitoid', 'granitoid', 'gneiss', 'granite'...
# 697  ['bif', 'laterite', 'granitoid', 'granitoid', ...
# 698    ['banded iron formation', 'bif', 'bif', 'bifs']
# 699                                                 []
# 700                                            ['bif']
#
#                                        MINERAL  \
# 0                                           []
# 1                                           []
# 2                                           []
# 3                                           []
# 4                           ['gold', 'zircon']
# ..                                         ...
# 696  ['quartz', 'feldspar', 'biotite', 'iron']
# 697                   ['hematite', 'goethite']
# 698                  ['magnetite', 'hematite']
# 699                                         []
# 700                      ['iron', 'magnetite']
#
#                                               STRAT  \
# 0                                                []
# 1                                                []
# 2                                                []
# 3     ['penneshaw formation', 'noganyer formation']
# 4    ['penneshaw formation', 'penneshaw formation']
# ..                                              ...
# 696                                              []
# 697                                              []
# 698                                              []
# 699                                              []
# 700                                              []
#
#                                               LOCATION  \
# 0                 ['norseman', 'norseman', 'norseman']
# 1                             ['norseman', 'norseman']
# 2                                                   []
# 3    ['norseman', 'gladstone', 'gladstone', 'gladst...
# 4                   ['gladstone', 'gladstone', 'long']
# ..                                                 ...
# 696                       ['south west', 'koolanooka']
# 697                                     ['koolanooka']
# 698  ['koolanooka', 'mid west', 'western australia'...
# 699              ['morawa', 'perenjori', 'koolanooka']
# 700  ['koolanooka', 'koolanooka', 'southwest', 'koo...
#
#                                             TIMESCALE  event_label  reviewed
# 0                                                  []            0     False
# 1                                                  []            0     False
# 2                                                  []            0     False
# 3                                                  []            0     False
# 4                ['archaean', 'archaean', 'archaean']            0     False
# ..                                                ...          ...       ...
# 696  ['archaean', 'tertiary', 'tertiary', 'archaean']            0     False
# 697                                      ['archaean']            0     False
# 698                                                []            0     False
# 699                                                []            0     False
# 700                                                []            0     False
#
# [701 rows x 15 columns]

# %%
# export csv when done
df.to_csv(f'group_{event_group}_labelled.csv')
print(f'Saved group_{event_group}_labelled.csv')
